# %%
import numpy as np
import pandas as pd
import sqlite3

import yfinance as yf

# %% [markdown]
# # GET DATA

# %%
dow_list_url = 'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average'
sp5_list_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
etf_list_url = 'https://etfdb.com/compare/volume/'

dow_list_raw = pd.read_html(dow_list_url)[1]
sp5_list_raw = pd.read_html(sp5_list_url)[0]
etf_list_raw = pd.read_html(etf_list_url)[0]

# %%
dow_list =  pd.DataFrame({
    'Symbol': dow_list_raw['Symbol'].str.replace('.', '-')})

sp5_list =  pd.DataFrame({
    'Symbol': sp5_list_raw['Symbol'].str.replace('.', '-'),
    'Name': sp5_list_raw['Security'],
    'Sector': sp5_list_raw['GICS Sector'],
    'Industry': sp5_list_raw['GICS Sub-Industry']})

etf_list =  pd.DataFrame({
    'Symbol': etf_list_raw['Symbol'],
    'Name': etf_list_raw['Name']})

dow_list = dow_list.merge(sp5_list)

display(dow_list)
display(sp5_list)
display(etf_list)
# Out:
#    Symbol                      Name                  Sector  \
# 0     MMM                        3M             Industrials
# 1     AXP          American Express              Financials
# 2    AMGN                     Amgen             Health Care
# 3    AAPL                     Apple  Information Technology
# 4      BA                    Boeing             Industrials
# 5     CAT               Caterpillar             Industrials
# 6     CVX                   Chevron                  Energy
# 7    CSCO                     Cisco  Information Technology
# 8      KO                 Coca-Cola        Consumer Staples
# 9     DIS                    Disney  Communication Services
# 10    DOW                       Dow               Materials
# 11     GS             Goldman Sachs              Financials
# 12     HD                Home Depot  Consumer Discretionary
# 13    HON                 Honeywell             Industrials
# 14    IBM                       IBM  Information Technology
# 15   INTC                     Intel  Information Technology
# 16    JNJ         Johnson & Johnson             Health Care
# 17    JPM            JPMorgan Chase              Financials
# 18    MCD                McDonald's  Consumer Discretionary
# 19    MRK                     Merck             Health Care
# 20   MSFT                 Microsoft  Information Technology
# 21    NKE                      Nike  Consumer Discretionary
# 22     PG          Procter & Gamble        Consumer Staples
# 23    CRM                Salesforce  Information Technology
# 24    TRV                 Travelers              Financials
# 25    UNH        UnitedHealth Group             Health Care
# 26     VZ                   Verizon  Communication Services
# 27      V                      Visa  Information Technology
# 28    WBA  Walgreens Boots Alliance        Consumer Staples
# 29    WMT                   Walmart        Consumer Staples
#
#                                       Industry
# 0                     Industrial Conglomerates
# 1                             Consumer Finance
# 2                                Biotechnology
# 3   Technology Hardware, Storage & Peripherals
# 4                          Aerospace & Defense
# 5        Construction Machinery & Heavy Trucks
# 6                         Integrated Oil & Gas
# 7                     Communications Equipment
# 8                                  Soft Drinks
# 9                       Movies & Entertainment
# 10                         Commodity Chemicals
# 11              Investment Banking & Brokerage
# 12                     Home Improvement Retail
# 13                    Industrial Conglomerates
# 14              IT Consulting & Other Services
# 15                              Semiconductors
# 16                             Pharmaceuticals
# 17                           Diversified Banks
# 18                                 Restaurants
# 19                             Pharmaceuticals
# 20                            Systems Software
# 21         Apparel, Accessories & Luxury Goods
# 22                           Personal Products
# 23                        Application Software
# 24               Property & Casualty Insurance
# 25                         Managed Health Care
# 26       Integrated Telecommunication Services
# 27       Data Processing & Outsourced Services
# 28                                 Drug Retail
# 29                Hypermarkets & Super Centers
#     Symbol           Name                  Sector  \
# 0      MMM             3M             Industrials
# 1      AOS    A. O. Smith             Industrials
# 2      ABT         Abbott             Health Care
# 3     ABBV         AbbVie             Health Care
# 4     ABMD        Abiomed             Health Care
# ..     ...            ...                     ...
# 499    YUM    Yum! Brands  Consumer Discretionary
# 500   ZBRA          Zebra  Information Technology
# 501    ZBH  Zimmer Biomet             Health Care
# 502   ZION  Zions Bancorp              Financials
# 503    ZTS         Zoetis             Health Care
#
#                                Industry
# 0              Industrial Conglomerates
# 1                     Building Products
# 2                 Health Care Equipment
# 3                       Pharmaceuticals
# 4                 Health Care Equipment
# ..                                  ...
# 499                         Restaurants
# 500  Electronic Equipment & Instruments
# 501               Health Care Equipment
# 502                      Regional Banks
# 503                     Pharmaceuticals
#
# [504 rows x 4 columns]
#    Symbol                                         Name
# 0    TQQQ                       ProShares UltraPro QQQ
# 1     SPY                       SPDR S&P 500 ETF Trust
# 2    SQQQ                 ProShares UltraPro Short QQQ
# 3    UVXY   ProShares Ultra VIX Short-Term Futures ETF
# 4     QQQ                            Invesco QQQ Trust
# ..    ...                                          ...
# 95   VTEB                 Vanguard Tax-Exempt Bond ETF
# 96   ICLN              iShares Global Clean Energy ETF
# 97    SSO                      ProShares Ultra S&P 500
# 98    XRT                          SPDR S&P Retail ETF
# 99    DIA  SPDR Dow Jones Industrial Average ETF Trust
#
# [100 rows x 2 columns]

# %%
dow_symbols = dow_list['Symbol'].values
sp5_symbols = sp5_list['Symbol'].values
etf_symbols = etf_list['Symbol'].values

symbols = np.unique(np.concatenate([
    dow_symbols,
    sp5_symbols,
    etf_symbols]))

histories_raw = yf.download(list(symbols))
# Out:
# [*********************100%***********************]  604 of 604 completed

# %%
histories = (histories_raw
    .stack()
    .reset_index()
    .rename(columns={'level_1': 'Symbol', 'Adj Close': 'Adj_Close'})
    .astype({'Date': 'datetime64[ns]', 'Volume': 'int64'}))

display(histories)
# Out:
#               Date Symbol   Adj_Close       Close        High         Low  \
# 0       1962-01-02    AEP    1.035685   34.312500   35.125000   34.312500
# 1       1962-01-02     BA    0.190931    0.823045    0.837449    0.823045
# 2       1962-01-02    CAT    0.495367    1.604167    1.619792    1.588542
# 3       1962-01-02    CNP    0.349574   10.783375   10.865333   10.783375
# 4       1962-01-02    CVX    0.361663    3.296131    3.296131    3.244048
# ...            ...    ...         ...         ...         ...         ...
# 4454003 2022-05-09    YUM  111.790001  111.790001  113.959999  111.410004
# 4454004 2022-05-09    ZBH  115.985001  115.985001  118.540001  115.370003
# 4454005 2022-05-09   ZBRA  336.160004  336.160004  341.719391  331.910004
# 4454006 2022-05-09   ZION   54.990002   54.990002   55.660000   54.230000
# 4454007 2022-05-09    ZTS  165.259995  165.259995  168.399994  164.285294
#
#                Open   Volume
# 0          0.000000     5800
# 1          0.837449   352350
# 2          1.604167   163200
# 3          0.000000    13879
# 4          0.000000   105840
# ...             ...      ...
# 4454003  113.750000   771706
# 4454004  118.660004   411361
# 4454005  335.000000   183611
# 4454006   55.090000   631180
# 4454007  167.000000  1103054
#
# [4454008 rows x 8 columns]

# %% [markdown]
# # SAVE DATA

# %%
# ! rm market.db
con = sqlite3.connect('market.db')

dow_list.to_sql('dow_list', con, index=False, if_exists='replace')
sp5_list.to_sql('sp5_list', con, index=False, if_exists='replace')
etf_list.to_sql('etf_list', con, index=False, if_exists='replace')

histories.to_sql('histories', con, index=False, if_exists='replace')
